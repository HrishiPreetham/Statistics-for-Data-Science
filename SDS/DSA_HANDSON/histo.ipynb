# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.random.normal(170,10,290)
plt.hist(x)
plt.show()

# %%
x=[21,22,23,4,5,6,77,8,9,10,31,32,33,34,35,36,37,18,49,50,100]
n_bins=[10,30,40,50,80,90]
bin_heights,bins,patches=plt.hist(x,n_bins,facecolor="red")
plt.show()

# %%
#cumulative histogram->sets the bin height as plotted(n)
plt.hist(x,cumulative=True,facecolor='red')
plt.show()

# %%
#plotting normal distribution
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
mu=100#mean
sigma=15#SD
x=mu+sigma*np.random.randn(10000)

num_bins=20
n,bins,patches=plt.hist(x,num_bins,facecolor="blue",alpha=0.5)
#adds a best fit line
y=mlab.normpdf(bins,mu,sigma)
plt.plot(bins,y,'r--')
plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ:$\mu=1005,$\sigma=15$')
plt.subplots_adjust(left=0.15)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [12], in <cell line: 11>()
#       9 n,bins,patches=plt.hist(x,num_bins,facecolor="blue",alpha=0.5)
#      10 #adds a best fit line
# ---> 11 y=mlab.normpdf(bins,mu,sigma)
#      12 plt.plot(bins,y,'r--')
#      13 plt.xlabel('Smarts')
#
# AttributeError: module 'matplotlib.mlab' has no attribute 'normpdf'

# %%
data=np.random.random((12,12))
plt.imshow(data,cmap='coolwarm')
plt.title('2-D Heat map')
plt.show()

# %%
import seaborn as sb
data_set=np.random.random((10,10))
plt.imshow(data_set,linewidth=0.8,cmap='autumn')
plt.title('2-D Heat map')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [16], in <cell line: 2>()
#       1 data_set=np.random.random((10,10))
# ----> 2 plt.imshow(data_set,linewidth=0.8,cmap='autumn')
#       3 plt.title('2-D Heat map')
#       4 plt.show()
#
# File ~\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py:456, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     450 if len(args) > name_idx:
#     451     warn_deprecated(
#     452         since, message="Passing the %(name)s %(obj_type)s "
#     453         "positionally is deprecated since Matplotlib %(since)s; the "
#     454         "parameter will become keyword-only %(removal)s.",
#     455         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 456 return func(*args, **kwargs)
#
# ...
